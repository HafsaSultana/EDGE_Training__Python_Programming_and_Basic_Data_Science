# %%
import pandas as pd

# %%
data = pd.read_csv('sample_data.csv')
data
# Out:
#             ID           Segment                   Country     Product   \
# 0      entry-1        Government                    Canada   Carretera
# 1      entry-2        Government                   Germany   Carretera
# 2      entry-3         Midmarket                    France   Carretera
# 3      entry-4         Midmarket                   Germany   Carretera
# 4      entry-5         Midmarket                    Mexico   Carretera
# ..         ...               ...                       ...          ...
# 695  entry-696    Small Business                    France    Amarilla
# 696  entry-697    Small Business                    Mexico    Amarilla
# 697  entry-698        Government                    Mexico     Montana
# 698  entry-699        Government                    Canada       Paseo
# 699  entry-700  Channel Partners  United States of America         VTT
#
#      Units Sold   Manufacturing Price    Sale Price     Gross Sales   \
# ...

# %%
print(data['Country'])
# Out:
# 0                        Canada
# 1                       Germany
# 2                        France
# 3                       Germany
# 4                        Mexico
#                  ...
# 695                      France
# 696                      Mexico
# 697                      Mexico
# 698                      Canada
# 699    United States of America
# Name: Country, Length: 700, dtype: object
