# %%
import pandas as pd
df = pd.read_csv('sample_data.csv')
df.head()
# Out:
#         ID     Segment  Country     Product   Units Sold  \
# 0  entry-1  Government   Canada   Carretera       1618.5
# 1  entry-2  Government  Germany   Carretera       1321.0
# 2  entry-3   Midmarket   France   Carretera       2178.0
# 3  entry-4   Midmarket  Germany   Carretera        888.0
# 4  entry-5   Midmarket   Mexico   Carretera       2470.0
#
#     Manufacturing Price    Sale Price   Gross Sales        Profit         Date
# 0                    3.0          20.0   $32,370.00    $16,185.00   2014-01-01
# 1                    3.0          20.0   $26,420.00    $13,210.00   2014-01-01
# 2                    3.0          15.0   $32,670.00    $10,890.00   2014-06-01
# 3                    3.0          15.0   $13,320.00     $4,440.00   2014-06-01
# 4                    3.0          15.0   $37,050.00    $12,350.00   2014-06-01

# %%
df.isin(['Mexico']).any()
# Out:
# ID                       False
# Segment                  False
# Country                   True
#  Product                 False
# Units Sold               False
#  Manufacturing Price     False
#  Sale Price              False
#  Gross Sales             False
#  Profit                  False
# Date                     False
# dtype: bool

# %%
df[df.isin(['Mexico'])].stack().index.tolist()
# Out:
# [(4, 'Country'),
#  (10, 'Country'),
#  (12, 'Country'),
#  (17, 'Country'),
#  (21, 'Country'),
#  (23, 'Country'),
#  (24, 'Country'),
#  (31, 'Country'),
#  (59, 'Country'),
#  (65, 'Country'),
#  (66, 'Country'),
#  (68, 'Country'),
#  (78, 'Country'),
#  (84, 'Country'),
#  (93, 'Country'),
#  (94, 'Country'),
#  (105, 'Country'),
#  (106, 'Country'),
#  (111, 'Country'),
#  (114, 'Country'),
#  (122, 'Country'),
#  (127, 'Country'),
#  (129, 'Country'),
#  (130, 'Country'),
#  (131, 'Country'),
#  (136, 'Country'),
#  (138, 'Country'),
#  (167, 'Country'),
#  (170, 'Country'),
#  (173, 'Country'),
#  (176, 'Country'),
#  (177, 'Country'),
#  (187, 'Country'),
#  (198, 'Country'),
#  (200, 'Country'),
#  (207, 'Country'),
#  (208, 'Country'),
#  (209, 'Country'),
#  (216, 'Country'),
#  (219, 'Country'),
#  (220, 'Country'),
#  (221, 'Country'),
#  (228, 'Country'),
#  (233, 'Country'),
#  (235, 'Country'),
#  (239, 'Country'),
#  (253, 'Country'),
#  (275, 'Country'),
# ...

# %%
df[df['Country'] == 'Mexico']
# Out:
#             ID           Segment Country     Product   Units Sold  \
# 4      entry-5         Midmarket  Mexico   Carretera       2470.0
# 10    entry-11         Midmarket  Mexico     Montana       2470.0
# 12    entry-13    Small Business  Mexico     Montana        958.0
# 17    entry-18         Midmarket  Mexico       Paseo        974.0
# 21    entry-22        Government  Mexico       Paseo        883.0
# ..         ...               ...     ...          ...         ...
# 673  entry-674        Government  Mexico       Paseo       2851.0
# 679  entry-680        Government  Mexico       Paseo       2151.0
# 682  entry-683  Channel Partners  Mexico        Velo        500.0
# 696  entry-697    Small Business  Mexico    Amarilla        546.0
# 697  entry-698        Government  Mexico     Montana       1368.0
#
#       Manufacturing Price    Sale Price     Gross Sales          Profit   \
# 4                      3.0          15.0     $37,050.00      $12,350.00
# ...

# %%
df[(df['Units Sold'] >= 1000) & (df['Units Sold'] <= 2000) & (df['Country'] == 'France')]
# Out:
#             ID     Segment Country     Product   Units Sold  \
# 8      entry-9  Government  France     Montana       1899.0
# 32    entry-33  Enterprise  France        Velo       1804.0
# 42    entry-43  Government  France         VTT       1527.0
# 48    entry-49  Government  France    Amarilla       1899.0
# 55    entry-56  Government  France       Paseo       1030.0
# ..         ...         ...     ...          ...         ...
# 642  entry-643  Government  France       Paseo       1731.0
# 646  entry-647  Government  France       Paseo       1922.0
# 657  entry-658  Government  France         VTT       1281.0
# 663  entry-664  Government  France    Amarilla       1731.0
# 666  entry-667  Enterprise  France   Carretera       1174.0
#
#       Manufacturing Price    Sale Price     Gross Sales          Profit   \
# 8                      5.0          20.0     $37,980.00      $18,990.00
# 32                   120.0         125.0   $2,25,500.00       $9,020.00
# ...
